# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
IMG_FOLDER = '/content/drive/MyDrive/NLP_driven_Invoice_Management_System/images'
print('Found', len(os.listdir(IMG_FOLDER)), 'files')
# Out:
# Found 10000 files

# %%
#installing dependencies
# !pip install pytesseract pillow transformers torch
#pytesseract for Optical Character Recognition(OCR)
#pillow to open image files
#transformers to use pre-trained transformer models like LayoutLMv3
#torch for backend
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 29.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !apt update
# !apt install tesseract-ocr
# !tesseract --version
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,721 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,994 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,953 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
#lets check whether we can read images and extract text using ocr
from PIL import Image
import pytesseract
import os

def ocr_image(image_path):
    img = Image.open(image_path)
    text = pytesseract.image_to_string(img)
    return text

# Ek sample image check karte hain
sample_image_path = os.path.join(IMG_FOLDER, os.listdir(IMG_FOLDER)[0])
print("Sample image path:", sample_image_path)

text = ocr_image(sample_image_path)
print("Extracted text:\n", text)
# Out:
# Sample image path: /content/drive/MyDrive/NLP_driven_Invoice_Management_System/images/Template5_Instance101.jpg
# Extracted text:
#  Invoice Date: 27-Jan-2009
# Invoice number SY2M74-545
# PO Number 62
#
#
#
# Bill to:Sean Nichols
# 35450 Brooke Freeway Suite 786
# Jacksonchester, FM 62786 US
# Tel:+(821)255-7277
# Email:christopherlamb@example.org
# Site:http://proctor.info!
#
#
#
# ay © Description Unitprice | Amount
#
#
#
# 100) 962924 | Ten create 5471 5471
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4.00 201569 __| Strategy because total 2228 e912
#
#
#
# ‘SUB_TOTAL : 143.83 USD
# TAX:VAT (6.63%): 9.53 USD
# BALANCE DUE : 151.09 USD
# Total in words: one hundred and fift-
# y-one point zero nine
#
# Note:Total payment due in 14 days.
#
# Address:233 Foster Gardens
#
# Johnburgh, ID 41900 US
#
# Bailey Group
# Email:paul73@example.com

# %%
import pandas as pd

# Empty list to store extracted data
data = []

# Loop over all images
for i, fname in enumerate(os.listdir(IMG_FOLDER)):
    image_path = os.path.join(IMG_FOLDER, fname)
    text = ocr_image(image_path)
    data.append({'filename': fname, 'extracted_text': text})

    if i % 100 == 0:
        print(f"Processed {i} images...")

# Convert to DataFrame
df = pd.DataFrame(data)

# Save as csv
csv_path = '/content/drive/MyDrive/NLP_driven_Invoice_Management_System/output/invoice_texts.csv'
os.makedirs(os.path.dirname(csv_path), exist_ok=True)
df.to_csv(csv_path, index=False)
print(f"CSV saved to {csv_path}")
# Out:
# Processed 0 images...
# Processed 100 images...
# Processed 200 images...
# Processed 300 images...
# Processed 400 images...
# Processed 500 images...
# Processed 600 images...
# Processed 700 images...
# Processed 800 images...
# Processed 900 images...
# Processed 1000 images...
# Processed 1100 images...
# Processed 1200 images...
# Processed 1300 images...
# Processed 1400 images...
# Processed 1500 images...
# Processed 1600 images...
# Processed 1700 images...
# Processed 1800 images...
# Processed 1900 images...
# Processed 2000 images...
# Processed 2100 images...
# Processed 2200 images...
# Processed 2300 images...
# Processed 2400 images...
# Processed 2500 images...
# Processed 2600 images...
# Processed 2700 images...
# Processed 2800 images...
# Processed 2900 images...
# Processed 3000 images...
# Processed 3100 images...
# Processed 3200 images...
# Processed 3300 images...
# Processed 3400 images...
# Processed 3500 images...
# Processed 3600 images...
# ...
